# %% [markdown]
# # Part (a): Exploring Data with R
# ### UE22CS342AA2 - Data Analytics
# - Credits to `Richa Shahi (CSE 2024)` and `Abhay K Iyengar (CSE 2024)` for this worksheet.
# - For any queries, reach out to Karthik Namboori - namkarthik2003@gmail.com

# %% [markdown]
# This worksheet aims to develop your understanding of summary statistics and basic visualizations through a pragmatic approach.

# %% [markdown]
# ## About the Dataset.
#
# - To make this worksheet interesting for you all, we have picked this dataset from Kaggle which comprises of the Movies and the metadata associated with it collected using The Movie Database (TMDB). It can be found [here](https://www.kaggle.com/datasets/karthiknamboori1/movie-datasets).  This dataset is the subset of this [Kaggle dataset](https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata).

# %% [markdown]
# - `title` - Name or Title of the movie.
# - `budget` - The budget of the movie in American Dollar(USD).
# - `genres` - The genres for  the entire movie.
# - `id` - The identifier for the movie in The Movie Database(TMDB).
# - `original_language` - The language associated with the original version of the film.
# - `popularity` - Lifetime popularity score of a movie that is impacted by attributes like number of votes, number of views, etc.
# - `release_date` - The release date of the movie.
# - `revenue` - The revenue generated by the movie in American Dollar(USD).
# - `runtime` - The duration of the movie in minutes.
# - `vote_average` - The average of all the votes on the scale of 10.
# - `vote_count` - The number of votes for a movie.
# - `director` - The director of the movie.

# %%
# Read the data from the CSV File.
data <- read.csv("/kaggle/input/movie-datasets/movie_dataset.csv")
head(data)
# Out:
#   budget   genres                                   id     original_language
# 1 2.37e+08 Action Adventure Fantasy Science-Fiction  19995 en
# 2 3.00e+08 Adventure Fantasy Action                    285 en
# 3 2.45e+08 Action Adventure Crime                   206647 en
# 4 2.50e+08 Action Crime Drama Thriller               49026 en
# 5 2.60e+08 Action Adventure Science-Fiction          49529 en
# 6 2.58e+08 Fantasy Action Adventure                    559 en
#   popularity release_date revenue    runtime
# 1 150.43758  10-12-2009   2787965087 162
# 2 139.08262  19-05-2007    961000000 169
# 3 107.37679  26-10-2015    880674609 148
# 4 112.31295  16-07-2012   1084939099 165
# 5  43.92699  07-03-2012    284139100 132
# 6 115.69981  01-05-2007    890871626 139
#   title                                    vote_average vote_count
# 1 Avatar                                   7.2          11800
# 2 Pirates of the Caribbean: At World's End 6.9           4500
# 3 Spectre                                  6.3           4466
# 4 The Dark Knight Rises                    7.6           9106
# 5 John Carter                              6.1           2124
# 6 Spider-Man 3                             5.9           3576
#   director
# 1 James Cameron
# 2 Gore Verbinski
# 3 Sam Mendes
# 4 Christopher Nolan
# 5 Andrew Stanton
# 6 Sam Raimi

# %% [markdown]
# ## Preliminary guided Exercises
# - ***Worksheets for this course will be on Kaggle.***
# - However if you are curious as to how R can be used locally, you will need R and RStudio installed.
# - Download the R programming language on your system. Then, make sure RStudio, the popular IDE for R, is installed. Click [here](https://www.youtube.com/watch?v=H9EBlFDGG4k) for the windows installation guide and [here](https://www.youtube.com/watch?v=I5WIMX4LK8M) for macOS.
# - RStudio provides a lot of useful functionality like R markdown, a script editor and GitHub integration.

# %% [markdown]
# ## Data Import

# %%
# loading the dataset - Upload the dataset under the input tab
# Example snippet
data <- read.csv('/kaggle/input/movie-datasets/movie_dataset.csv', header=TRUE)

# %% [markdown]
# - The `header = TRUE` argument specifies that the first row of your data contains the variable names. If this is not the case you can specify header = FALSE (this is the default value so you can omit this argument entirely).

# %% [markdown]
# ## Compact Summary
# - Use the `str()` function to return a compact and informative summary of the DataFrame.

# %%
str(data)
# Out:
# 'data.frame':	4041 obs. of  12 variables:
#  $ budget           : num  2.37e+08 3.00e+08 2.45e+08 2.50e+08 2.60e+08 2.58e+08 2.60e+08 2.80e+08 2.50e+08 2.50e+08 ...
#  $ genres           : chr  "Action Adventure Fantasy Science-Fiction" "Adventure Fantasy Action" "Action Adventure Crime" "Action Crime Drama Thriller" ...
#  $ id               : int  19995 285 206647 49026 49529 559 38757 99861 767 209112 ...
#  $ original_language: chr  "en" "en" "en" "en" ...
#  $ popularity       : num  150.4 139.1 107.4 112.3 43.9 ...
#  $ release_date     : chr  "10-12-2009" "19-05-2007" "26-10-2015" "16-07-2012" ...
#  $ revenue          : num  2.79e+09 9.61e+08 8.81e+08 1.08e+09 2.84e+08 ...
#  $ runtime          : num  162 169 148 165 132 139 100 141 153 151 ...
#  $ title            : chr  "Avatar" "Pirates of the Caribbean: At World's End" "Spectre" "The Dark Knight Rises" ...
#  $ vote_average     : num  7.2 6.9 6.3 7.6 6.1 5.9 7.4 7.3 7.4 5.7 ...
#  $ vote_count       : int  11800 4500 4466 9106 2124 3576 3330 6767 5293 7004 ...
#  $ director         : chr  "James Cameron" "Gore Verbinski" "Sam Mendes" "Christopher Nolan" ...

# %% [markdown]
# - Here we see that data is a ‘data.frame’ object which contains 4041 rows and 12 variables (columns). Each the variables are listed along with their data class and the first 10 values.

# %% [markdown]
# ## Summary Statistics
# - To access the data in any of the variables (columns) in our data frame we can use the $ notation. Indexing in R starts at 1, which means the first element is at index 1. Access the first 10 values of the title column:

# %%
data$title[1:10]
# Out:
#  [1] "Avatar"
#  [2] "Pirates of the Caribbean: At World's End"
#  [3] "Spectre"
#  [4] "The Dark Knight Rises"
#  [5] "John Carter"
#  [6] "Spider-Man 3"
#  [7] "Tangled"
#  [8] "Avengers: Age of Ultron"
#  [9] "Harry Potter and the Half-Blood Prince"
# [10] "Batman v Superman: Dawn of Justice"

# %% [markdown]
# - We can assign a column to another variable and calculate a mean of a numeric variable or get a summary of a variable using the `summary()` function.

# %% [markdown]
# *Problem*: Can you find the summary statistics of the vote_count and the title columns ?

# %%
# Your answer here.
summary(data$vote_count[1:10])
summary(data$title[1:10])
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    2124    3798    4896    5797    6945   11800
#    Length     Class      Mode
#        10 character character

# %% [markdown]
# ## Scatter Plots and Line Plots
# - Plotting and visualisation are an essential aspect in data analysis!
# - The most common high level function used to produce plots in R is the `plot` function.

# %%
# par(mfrow = c(1,2)) # To plot different plots in the same row
plot(data$budget, type="p") # scatter plot of budget vs the index

# %% [markdown]
# *Problem*: Can you show a line plot between the revenue and the index?

# %%
# Your answer here.
plot(data$revenue, type="p")

# %% [markdown]
# ## Sorting a data frame
# - To sort a dataframe with respect to a column we can use the order() function. Let us sort the dataframe to get the top 10 highest grossing movies.

# %%
sorted_data <- data[order(data$revenue, decreasing = TRUE), ] # To sort in descending order 

# The head function is used to get the first 10 rows
top_10_rows <- head(sorted_data, n = 10)

top_10_rows
# Out:
#     budget   genres                                    id     original_language
# 1   2.37e+08 Action Adventure Fantasy Science-Fiction   19995 en
# 26  2.00e+08 Drama Romance Thriller                       597 en
# 17  2.20e+08 Science-Fiction Action Adventure           24428 en
# 29  1.50e+08 Action Adventure Science-Fiction Thriller 135397 en
# 45  1.90e+08 Action                                    168259 en
# 8   2.80e+08 Action Adventure Science-Fiction           99861 en
# 125 1.50e+08 Animation Adventure Family                109445 en
# 32  2.00e+08 Action Adventure Science-Fiction           68721 en
# 530 7.40e+07 Family Animation Adventure Comedy         211672 en
# 27  2.50e+08 Adventure Action Science-Fiction          271110 en
#     popularity release_date revenue    runtime title
# 1   150.43758  10-12-2009   2787965087 162     Avatar
# 26  100.02590  18-11-1997   1845034188 194     Titanic
# 17  144.44863  25-04-2012   1519557910 143     The Avengers
# 29  418.70855  09-06-2015   1513528810 124     Jurassic World
# 45  102.32222  01-04-2015   1506249360 137     Furious 7
# 8   134.27923  22-04-2015   1405403694 141     Avengers: Age of Ultron
# 125 165.12537  27-11-2013   1274219009 102     Frozen
# 32   77.68208  18-04-2013   1215439994 130     Iron Man 3
# 530 875.58131  17-06-2015   1156730962  91     Minions
# 27  198.37240  27-04-2016   1153304495 147     Captain America: Civil War
#     vote_average vote_count director
# 1   7.2          11800      James Cameron
# 26  7.5           7562      James Cameron
# 17  7.4          11776      Joss Whedon
# 29  6.5           8662
# 45  7.3           4176      James Wan
# 8   7.3           6767      Joss Whedon
# 125 7.3           5295      Chris Buck
# 32  6.8           8806      Shane Black
# 530 6.4           4571      Kyle Balda
# 27  7.1           7241      Anthony Russo

# %% [markdown]
# *Problem*: Can you sort the `vote_average` column in descending order?

# %%
# Your answer here.
sorted_data <- data[order(data$vote_average, decreasing = TRUE), ]
top_10_rows <- head(sorted_data, n = 10)

top_10_rows
# Out:
#      budget   genres                       id     original_language popularity
# 2987        0 Comedy                        89861 en                  0.356495
# 3408        0 Comedy Drama Family           78373 en                  0.376662
# 3570        1 Romance Comedy Drama         361505 en                  0.094105
# 3915        0 Comedy                        40963 en                  0.092100
# 3365        0                              346081 en                  0.296981
# 2112        0 Western Action Drama History  69848 en                  0.910529
# 1707 25000000 Drama Crime                     278 en                136.747729
# 2569 10500000 Drama Comedy                  88641 en                  0.037073
# 2847  6000000 Drama Crime                     238 en                143.659698
# 641  63000000 Drama                           550 en                146.757391
#      release_date revenue   runtime title                    vote_average
# 2987 12-06-1998           0  99     Stiff Upper Lips         10.0
# 3408 01-05-1998      565592  97     Dancer, Texas Pop. 81    10.0
# 3570 07-07-2015           0  90     Me You and Five Bucks    10.0
# 3915 01-01-2006           0   0     Little Big Top           10.0
# 3365 26-06-2015           0   0     Sardaarji                 9.5
# 2112 02-08-1999           0 121     One Man's Hero            9.3
# 1707 23-09-1994    28341469 142     The Shawshank Redemption  8.5
# 2569 02-09-1994      123509  99     There Goes My Baby        8.5
# 2847 14-03-1972   245066411 175     The Godfather             8.4
# 641  15-10-1999   100853753 139     Fight Club                8.3
#      vote_count director
# 2987    1       Gary Sinyor
# 3408    1       Tim McCanlies
# 3570    2
# 3915    1
# 3365    2       Rohit Jugraj
# 2112    2       Lance Hool
# 1707 8205       Frank Darabont
# 2569    2       Floyd Mutrux
# 2847 5893       Francis Ford Coppola
# 641  9413       David Fincher

# %% [markdown]
# ## Column Transformation
# - Highest Revenue might not be the right indicator for a successful movie. So lets plot the ROI (Return on Investment for all movies)
#
# - `ROI = Net Return/Cost of Investment`

# %%
data$ROI = data$revenue / data$budget
# Print the first 5 rows with their title and ROI
data[1:5, c("title", "ROI")]
# Out:
#   title                                    ROI
# 1 Avatar                                   11.763566
# 2 Pirates of the Caribbean: At World's End  3.203333
# 3 Spectre                                   3.594590
# 4 The Dark Knight Rises                     4.339756
# 5 John Carter                               1.092843

# %% [markdown]
# ## Data Pre-processing
# - A lot of times real-world datasets are not curated and cleaned. Values are not stored in proper formats and hence requires cleaning and appropriate transformation before the data is suitable for analysis. In our case we see that the genre is stored as a string. Lets us split the string to get all genre labels.

# %%
# Convert the space-separated string of genres to a list of genres for each movie
data$genres <- strsplit(data$genres, " ")

# Extract the individual genres and count their occurrences
label_counts <- table(unlist(data$genres)) # label_counts will be a data frame with "Var1" anf "freq"
# Sort the counts in descending order
label_counts <- sort(label_counts, decreasing = TRUE)

# %%
label_counts
# Out:
#           Drama          Comedy        Thriller          Action         Romance
#            1875            1386            1073            1029             731
#       Adventure           Crime Science-Fiction          Family          Horror
#             714             593             476             426             418
#         Fantasy         Mystery       Animation         History           Music
#             356             295             207             166             143
#             War     Documentary         Western         Foreign        TV-Movie
#             132              96              66              34               5

# %% [markdown]
# ## Using the ggplot2 Library

# %%
#Load the ggplot2 library
library(ggplot2)

# Make sure you have label_counts data frame with "Var1" and "Freq" columns
# Convert the table object to a data frame
label_counts_df <- as.data.frame(label_counts)

# Plot the bar chart using ggplot2
ggplot(label_counts_df, aes(x = Var1, y = Freq)) +
geom_bar(stat = "identity", fill = "skyblue") +
labs(x = "Genre", y = "Number of Movies", title = "Number of Movies for Each Genre") 
theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# List of 1
#  $ axis.text.x:List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : num 1
#   ..$ vjust        : NULL
#   ..$ angle        : num 45
#   ..$ lineheight   : NULL
#   ..$ margin       : NULL
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi FALSE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  - attr(*, "class")= chr [1:2] "theme" "gg"
#  - attr(*, "complete")= logi FALSE
#  - attr(*, "validate")= logi TRUE

# %%
# Showing the top 5 frequencies
head(label_counts_df)
# Out:
#   Var1      Freq
# 1 Drama     1875
# 2 Comedy    1386
# 3 Thriller  1073
# 4 Action    1029
# 5 Romance    731
# 6 Adventure  714

# %%
nrow(data)
# Out:
# [1] 4041

# %% [markdown]
# - Its evident that close to 50% of the data is of the `Drama` genre.

# %% [markdown]
# *fin*
