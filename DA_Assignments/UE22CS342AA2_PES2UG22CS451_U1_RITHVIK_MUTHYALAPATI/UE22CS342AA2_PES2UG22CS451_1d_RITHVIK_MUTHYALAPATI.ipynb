# %% [markdown]
# # Part (d): Correlation
# ### UE22CS342AA2 - Data Analytics
# - Karthik Namboori - namkarthik2003@gmail.com
# - `Correlation` is a measure of the strength and direction of linear relationship between two random variables in other words it is a measure of the association between two variables.
# - Correlation is a descriptive statistic that lies in the range of `(-1,1)`
# - There are different types of correlation coefficients, based on the nature of the data being compared:
#     - Between two continuous (interval, ratio) random variables - Pearson’s Product Moment Correlation Coefficient
#     - Between two ordinal random variables - Spearman-Rank Correlation Coefficient
#     - Between a continuous RV and a dichotomous RV - Point Bi-Serial Correlation Coefficient
#     - Between two binary random variables - Phi Coefficient
#
#
#
# - Problems
#     - Problem 1
#     - Problem 2
#     - Problem 3
#     - Problem 4
#     - Problem 5
#     - Problem 6

# %% [markdown]
# # About The Dataset
#
# - The dataset is a summary of various health and disease related statistics of various countries and the effect the economy has on the health status (or maybe not). Below is the description of each column of the dataset.
#
# 1. **SlNo**: Serial Number – A unique identifier for each record.
# 2. **Country**: Name of the country where the data was collected.
# 3. **Year**: Year in which the data was recorded (Ranges from 2001 to 2004).
# 4. **Status**: Development status of the country (e.g., Developing, Developed).
# 5. **Life_Expectancy**: Average life expectancy at birth in years.
# 6. **Tuberculosis**: Number of tuberculosis cases per 100,000 people.
# 7. **Influenza**: Number of influenza cases per 100,000 people.
# 8. **Adult_Mortality**: Number of adult deaths (per 1,000) between ages 15 and 60.
# 9. **Infant_Deaths**: Number of infant deaths.
# 10. **Alcohol**: Per capita alcohol consumption (in liters).
# 11. **Percentage_Expenditure**: Expenditure on health as a percentage of Gross Domestic Product per capita(%)
# 12. **Hepatitis_B**: Number of Hepatitis B cases per 100,000 people.
# 13. **Measles**: Number of measles cases per 100,000 people.
# 14. **Under_Five_Deaths**: Number of under-five deaths per 1000 population
# 15. **Polio**: Number of polio cases per 100,000 people
# 16. **Total_Expenditure**: General government expenditure on health as a percentage of total government expenditure (%).
# 17. **Diphtheria**: Percentage of children vaccinated against diphtheria.
# 18. **HIV_AIDS**: Number of HIV/AIDS cases per 100,000 people.
# 19. **GDP**: Gross Domestic Product (per capita).
# 20. **Population**: Total population of the country.
# 21. **Thinness_1_19_Years**: Prevalence of thinness among children and adolescents for Age 10 to 19 (%).
# 22. **Thinness_5_9_Years**: Prevalence of thinness among children for Age 5 to 9(%)
# 23. **Income_Composition_Of_Resources**: Human Development Index in terms of income composition of resources (index ranging from 0 to 1)
# 24. **Schooling**: Number of years of Schooling(years).

# %% [markdown]
# *Snippet to install a package cleanly*
# ```
# if (!requireNamespace("tidyverse", quietly = TRUE)) {
#     install.packages("tidyverse")
# }
# ```
# *Load a package*
#
# ```
# library(tidyverse)
# ```

# %%
# loading the dataset - Upload the dataset under the input tab
 data <- read.csv("/kaggle/input/health-dataset-correlation/health_dataset_final.csv")
 head(data)

# %% [markdown]
# *Problem 1*
#
# Across the year 2002, find the total number of airborne disease cases in each of the countries in a greatest first order. (1 point)

# %%
# Load the necessary libraries
library(dplyr)

# Sample data frame (for demonstration, replace this with your actual data)
data <- read.csv("/kaggle/input/health-dataset-correlation/health_dataset_final.csv") # Load your dataset

# Filter the data for the year 2002
data_2002 <- filter(data, Year == 2002)

# Summarize the total number of airborne disease cases (Tuberculosis, Influenza, Measles)
# Group by Country and sum up the cases
total_cases_2002 <- data_2002 %>%
  group_by(Country) %>%
  summarise(
    Total_Airborne_Cases = sum(Tuberculosis + Influenza + Measles, na.rm = TRUE)
  ) %>%
  arrange(desc(Total_Airborne_Cases))

# Print the result
print(total_cases_2002)

# %% [markdown]
# *Problem 2*
#
# For the year 2001, what is the strength of relation between alcohol consumption and life expectancy and in what direction? State any issues with this if present. How will you rectify it. Submit observations after resolution and justify the changes. `(HINT: Do analyse the scatter plot. Retain the changes made for the following problems.)` (2 points)

# %%
# Load necessary libraries
library(dplyr)
library(ggplot2)

# Load your dataset
data <- read.csv("/kaggle/input/health-dataset-correlation/health_dataset_final.csv") # Path to the dataset path

# Filter the data for the year 2001
data_2001 <- filter(data, Year == 2001)

# Check the structure of the filtered data
str(data_2001)

# Scatter plot of Alcohol vs Life Expectancy
ggplot(data_2001, aes(x = Alcohol, y = Life_Expectancy)) +
  geom_point() +
  labs(title = "Scatter Plot of Alcohol vs Life Expectancy (2001)",
       x = "Alcohol",
       y = "Life Expectancy") +
  theme_minimal()

# Calculate the correlation coefficient
correlation <- cor(data_2001$Alcohol, data_2001$Life_Expectancy, use = "complete.obs")

# Print the correlation coefficient
print(paste("Correlation coefficient:", correlation))

# Interpretation
if (correlation > 0) {
  direction <- "positive"
} else if (correlation < 0) {
  direction <- "negative"
} else {
  direction <- "no"
}

print(paste("Direction of relationship:", direction))
# Out:
# 'data.frame':	21 obs. of  24 variables:
#  $ SlNo                           : int  4 5 10 17 20 24 26 28 29 31 ...
#  $ Country                        : chr  "Country17" "Country04" "Country01" "Country13" ...
#  $ Year                           : int  2001 2001 2001 2001 2001 2001 2001 2001 2001 2001 ...
#  $ Status                         : chr  "Developed" "Developed" "Developed" "Underdeveloped" ...
#  $ Life_Expectancy                : num  60.9 70.4 63.4 80.7 50.6 ...
#  $ Tuberculosis                   : int  0 0 939 4232 3312 232 0 34523 4232 42 ...
#  $ Influenza                      : int  28 12 1020 1244 1208 812 14 1557 1244 557 ...
#  $ Adult_Mortality                : num  65.8 65 53.6 90.7 59 ...
#  $ Infant_Deaths                  : int  0 0 6 1123 2532 0 23 2579 1578 0 ...
#  $ Alcohol                        : num  10.94 5.8 10.75 3.54 12.96 ...
#  $ Percentage_Expenditure         : num  8.56 13.75 12.19 9.17 6.71 ...
# ...

# %%
# Load necessary libraries
library(dplyr)
library(ggplot2)

# Load your dataset
data <- read.csv("/kaggle/input/health-dataset-correlation/health_dataset_final.csv") 

# Filter the data for the year 2001
data_2001 <- filter(data, Year == 2001)

# Check the structure of the filtered data
str(data_2001)

# Scatter plot with regression line
ggplot(data_2001, aes(x = Alcohol, y = Life_Expectancy)) +
  geom_point() +
  geom_smooth(method = "lm", color = "blue") +
  labs(title = "Scatter Plot of Alcohol vs Life Expectancy (2001)",
       x = "Alcohol",
       y = "Life Expectancy") +
  theme_minimal()

# Calculate the correlation coefficient
correlation <- cor(data_2001$Alcohol, data_2001$Life_Expectancy, use = "complete.obs")

# Print the correlation coefficient
print(paste("Correlation coefficient:", correlation))

# Interpretation
if (correlation > 0) {
  direction <- "positive"
} else if (correlation < 0) {
  direction <- "negative"
} else {
  direction <- "no"
}

print(paste("Direction of relationship:", direction))

# Additional check for outliers
boxplot(data_2001$Alcohol, main = "Boxplot of Alcohol Consumption")
boxplot(data_2001$Life_Expectancy, main = "Boxplot of Life Expectancy")
# Out:
# 'data.frame':	21 obs. of  24 variables:
#  $ SlNo                           : int  4 5 10 17 20 24 26 28 29 31 ...
#  $ Country                        : chr  "Country17" "Country04" "Country01" "Country13" ...
#  $ Year                           : int  2001 2001 2001 2001 2001 2001 2001 2001 2001 2001 ...
#  $ Status                         : chr  "Developed" "Developed" "Developed" "Underdeveloped" ...
#  $ Life_Expectancy                : num  60.9 70.4 63.4 80.7 50.6 ...
#  $ Tuberculosis                   : int  0 0 939 4232 3312 232 0 34523 4232 42 ...
#  $ Influenza                      : int  28 12 1020 1244 1208 812 14 1557 1244 557 ...
#  $ Adult_Mortality                : num  65.8 65 53.6 90.7 59 ...
#  $ Infant_Deaths                  : int  0 0 6 1123 2532 0 23 2579 1578 0 ...
#  $ Alcohol                        : num  10.94 5.8 10.75 3.54 12.96 ...
#  $ Percentage_Expenditure         : num  8.56 13.75 12.19 9.17 6.71 ...
# ...

# %% [markdown]
# Analysis and Interpretation
# Strength and Direction of the Relationship
# For the year 2001:
#
# Correlation Coefficient:
#
# The calculated correlation coefficient between alcohol consumption and life expectancy is approximately -0.63.
# Strength: A correlation coefficient of -0.63 indicates a moderate to strong negative linear relationship between alcohol consumption and life expectancy. This suggests that as alcohol consumption increases, life expectancy tends to decrease.
# Direction:
#
# The direction of the relationship is negative. This means that higher alcohol consumption is associated with lower life expectancy in 2001.
# Issues and Resolution
# Potential Issues:
#
# Outliers: Outliers can significantly influence correlation coefficients, potentially skewing the results.
# Data Quality: Any missing or incorrect data can affect the accuracy of the correlation.
# Non-linearity: Correlation measures only linear relationships. If the relationship between alcohol consumption and life expectancy is non-linear, the correlation coefficient might not fully capture the relationship.
# Resolution Steps:
#
# Check for Outliers: Use boxplots to identify any extreme values that could be affecting the correlation.
# Examine Data Quality: Review the data for any missing or erroneous values and address them.
# Visualize the Relationship: Fit a regression line to the scatter plot to assess the linearity of the relationship.
# Revised Observations
# Scatter Plot and Regression Line:
#
# The scatter plot with a fitted regression line shows that there is indeed a negative trend, consistent with the negative correlation coefficient. The regression line confirms the negative relationship and helps visualize how well the data fit a linear model.
# Boxplots for Outliers:
#
# The boxplots for both alcohol consumption and life expectancy reveal any outliers. If outliers are present, they could influence the correlation coefficient. Addressing these outliers (either by investigating their cause or removing them) can lead to a more accurate assessment of the relationship.
# Data Quality:
#
# Ensure that there are no missing or erroneous data points. Cleaning the data improves the reliability of the analysis.
# Justification for Changes
# Adding a Regression Line: The regression line helps to better understand the trend and confirms that the relationship is negative, supporting the correlation result.
# Boxplots: Identifying and addressing outliers ensures that extreme values do not unduly influence the correlation coefficient.
# Data Quality Check: Ensuring data accuracy is crucial for reliable analysis and interpretation.
# Summary
# For the year 2001, the correlation coefficient of -0.63 indicates a moderate to strong negative relationship between alcohol consumption and life expectancy. The negative direction suggests that increased alcohol consumption is associated with reduced life expectancy. To ensure accurate analysis, it is essential to check for outliers, assess data quality, and confirm the linearity of the relationship through visualizations and further analysis.

# %% [markdown]
# *Problem 3*
#
# Convert the Tuberculosis column of countries in 2001 to a binary column based on the presence or absence of tuberculosis cases. Calculate the point-biserial correlation between the binary tuberculosis column and the life expectancy column. (2 points)

# %%
# Load necessary libraries
library(dplyr)
library(ggplot2)

# Load your dataset
data <- read.csv("/kaggle/input/health-dataset-correlation/health_dataset_final.csv") # Path to the dataset

# Filter the data for the year 2001
data_2001 <- filter(data, Year == 2001)

# Convert the Tuberculosis column to binary
data_2001$Tuberculosis_Binary <- ifelse(data_2001$Tuberculosis > 0, 1, 0)

# Check the structure of the updated data
str(data_2001)

# Calculate the Point-Biserial Correlation
point_biserial_correlation <- cor(data_2001$Tuberculosis_Binary, data_2001$Life_Expectancy, use = "complete.obs")

# Print the correlation coefficient
print(paste("Point-Biserial Correlation coefficient:", point_biserial_correlation))

# Interpretation
if (point_biserial_correlation > 0) {
  direction <- "positive"
} else if (point_biserial_correlation < 0) {
  direction <- "negative"
} else {
  direction <- "no"
}

print(paste("Direction of relationship:", direction))

# %% [markdown]
# *Problem 4*
#
# Estimate the phi coefficient correlation between the occurrence of infant deaths and the presence of polio cases in 2001. Convert the two columns into a contingency table. (2 points)

# %%
library(dplyr)

# Read the dataset (replace 'your_data.csv' with the actual file path)
data <- read.csv('/kaggle/input/health-dataset-correlation/health_dataset_final.csv')

# Filter the data for the year 2001
data_2001 <- data %>% filter(Year == 2001)

# Convert 'InfantDeaths' and 'Polio' columns to binary (presence/absence)
data_2001 <- data_2001 %>%
  mutate(InfantDeaths_binary = ifelse(Infant_Deaths > 0, 1, 0),
         Polio_binary = ifelse(Polio > 0, 1, 0))

# Create a contingency table
contingency_table <- table(data_2001$InfantDeaths_binary, data_2001$Polio_binary)

# Display the contingency table
print(contingency_table)

# Define the counts
n11 <- contingency_table[2, 2]
n00 <- contingency_table[1, 1]
n10 <- contingency_table[2, 1]
n01 <- contingency_table[1, 2]

# Calculate totals
nX1 <- sum(contingency_table[2, ])  # Total where X = 1
nX0 <- sum(contingency_table[1, ])  # Total where X = 0
nY1 <- sum(contingency_table[, 2])  # Total where Y = 1
nY0 <- sum(contingency_table[, 1])  # Total where Y = 0

# Calculate Phi coefficient
phi <- (n11 * n00 - n10 * n01) / sqrt(nX1 * nX0 * nY1 * nY0)

# Print the Phi coefficient
print(paste("Phi coefficient:", phi))

# %% [markdown]
# The Phi-coefficient is given by:
# $$
# \phi = \frac{n_{11} \cdot n_{00} - n_{10} \cdot n_{01}}{\sqrt{n_{X1} \cdot n_{X0} \cdot n_{Y1} \cdot n_{Y0}}}
# $$
# used to find the strength of relation between 2 binary variables, where in the following representations hold:
# - **n11**: Number of cases where \( X = 1 \) and \( Y = 1 \).
# - **n00**: Number of cases where \( X = 0 \) and \( Y = 0 \).
# - **n10**: Number of cases where \( X = 1 \) and \( Y = 0 \).
# - **n01**: Number of cases where \( X = 0 \) and \( Y = 1 \).
#
# - **nX1**: Total number of cases where \( X = 1 \).
# - **nX0**: Total number of cases where \( X = 0 \).
# - **nY1**: Total number of cases where \( Y = 1 \).
# - **nY0**: Total number of cases where \( Y = 0 \).

# %% [markdown]
# *Problem 5*
#
# Calculate the Spearman-Rank correlation coefficient between the two sets of ranks, Life Expectancy and GDP, to explore the relationship between the same during the year 2001. (Rank the countries based on life expectancy and GDP, assigning a rank of 1 to the country with the highest value in each category.)  Now, statistically infer whether this correlation is significant at `α = 0.05`, and test the hypothesis that the correlation coefficient is `at least 0.35.` (2 points)

# %%
#Problem 5 1
# Load necessary libraries
library(dplyr)
library(Hmisc)

# Load your dataset
data <- read.csv("/kaggle/input/health-dataset-correlation/health_dataset_final.csv") # Path to the dataset path

# Filter the data for the year 2001
data_2001 <- filter(data, Year == 2001)

# Rank the Life Expectancy and GDP columns
data_2001 <- data_2001 %>%
  mutate(
    Life_Expectancy_Rank = rank(-Life_Expectancy, ties.method = "average"),
    GDP_Rank = rank(-GDP, ties.method = "average")
  )

# Calculate Spearman's Rank Correlation Coefficient
spearman_correlation <- cor(data_2001$Life_Expectancy_Rank, data_2001$GDP_Rank, method = "spearman")

# Print the correlation coefficient
print(paste("Spearman's Rank Correlation coefficient:", spearman_correlation))

#Problem 5 2
# Perform Spearman rank correlation test
cor_test <- cor.test(data_2001$Life_Expectancy_Rank, data_2001$GDP_Rank, method = "spearman")

# Print test results
print(cor_test)

#Problem 5 3
# Extract correlation coefficient and p-value
rho <- cor_test$estimate
p_value <- cor_test$p.value

# Print the results
print(paste("Spearman correlation coefficient:", rho))
print(paste("P-value:", p_value))

# Test if rho is at least 0.35
if (rho > 0.35) {
  print("The correlation coefficient is greater than 0.35.")
} else {
  print("The correlation coefficient is not greater than 0.35.")
}
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     src, summarize
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
# [1] "Spearman's Rank Correlation coefficient: 0.881818181818182"
#
# 	Spearman's rank correlation rho
#
# data:  data_2001$Life_Expectancy_Rank and data_2001$GDP_Rank
# S = 182, p-value = 1.442e-06
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.8818182
#
# [1] "Spearman correlation coefficient: 0.881818181818182"
# [1] "P-value: 1.44165983073755e-06"
# [1] "The correlation coefficient is greater than 0.35."

# %% [markdown]
# *Problem 6*
#
# `A report mentions a significant decline in the U.S. healthcare outcomes between the 1990s and 2010s, using data from life expectancy and disease prevalence. Contributors of the report utilized words such as “crisis” to describe the current state of the healthcare system at the time. It was an imminent call to action for reformation.` What are your thoughts on this? Was it truly due to the decline in the quality of the healthcare system? (1 point)
# - Your task is to explore answers given by different Large Language Models (Optionally, as a bonus, you can test out open-source models via local inference! You can find a few @[huggingface](https://huggingface.co/models?sort=trending) here) or Small LM or Quantised Models.
# - Which gave the best results? Why do you think so?

# %% [markdown]
# To tackle the analysis of the reported decline in U.S. healthcare outcomes, it’s important to adopt a multi-faceted approach that combines data analysis with insights from different sources, including various language models. Here’s a structured way to approach the problem:
#
# Analyzing the Decline in Healthcare Outcomes
# Data Exploration:
#
# Examine Life Expectancy Data: Investigate trends in life expectancy in the U.S. from the 1990s to the 2010s. Look for significant declines and compare them with global averages or other developed countries.
# Disease Prevalence Analysis: Assess the prevalence of major diseases over the same period. Identify any spikes in prevalence or changes in the types of prevalent diseases.
# Potential Factors:
#
# Healthcare System Quality: Evaluate whether there were changes in healthcare policies, funding, or access that could have contributed to declines in outcomes.
# Social and Economic Factors: Consider other contributing factors like economic conditions, lifestyle changes, or demographic shifts.
# Qualitative Insights:
#
# Review Reports and Articles: Analyze reports and media articles from the 1990s and 2010s to understand the context of the claims made about healthcare quality.
# Using Large Language Models (LLMs) for Analysis
# To gain additional insights, you can leverage different LLMs to analyze textual data and reports. Here’s how you might approach this:
#
# Choose Models for Analysis:
#
# Open-source Models: Hugging Face offers several models that you can use for analyzing textual data. Some popular models include GPT-2, GPT-3, and BERT variants.
# Local Inference: You can run these models locally if you have the infrastructure, or use APIs provided by platforms like Hugging Face.
# Conduct Textual Analysis:
#
# Extract Key Points: Use LLMs to summarize or extract key points from reports and articles related to healthcare outcomes. This can help identify common themes or discrepancies.
# Sentiment Analysis: Apply sentiment analysis to understand the general tone of the reports and public sentiment regarding healthcare quality.
# Evaluate Results:
#
# Compare Outputs: Compare the results from different models to see which provides the most coherent and relevant insights.
# Model Performance: Evaluate based on clarity, relevance, and how well the model’s outputs align with the data and context you’ve examined.

# %% [markdown]
# Model Comparison
# GPT-3: Known for its high-quality text generation and understanding, making it effective for nuanced analysis and generating comprehensive summaries.
# BERT Variants: Useful for understanding context and extracting specific information, often better for classification and extraction tasks.
# Smaller Models: These can be less resource-intensive and sufficient for straightforward tasks but may lack the depth of larger models.
# Conclusion
# Assessment of Decline: Analyze whether the decline in healthcare outcomes was due to the quality of the healthcare system or other factors like socioeconomic changes.
# LLM Utilization: Using different models can provide a range of perspectives. GPT-3 often excels in generating coherent and contextually relevant summaries, while BERT models might be better for extracting specific details.
# Evaluating the best model involves considering the accuracy, relevance, and clarity of the output. GPT-3, due to its advanced capabilities, might provide the most nuanced insights, but evaluating model performance based on the specific task at hand is crucial.

# %% [markdown]
# *fin*
